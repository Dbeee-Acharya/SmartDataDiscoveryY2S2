# %%
import pandas as pd

# %%
df = pd.read_csv('data_detail.csv')

# %%
df
# Out:
#     name  age address  mark  sex
# 0    ram   22     ktm    77    1
# 1  shyam   21     brt    81    1
# 2   sita   23     ktm    83    0
# 3   sita   19     jkp    91    0
# 4    ram   22     ktm    77    1
# 5    ram   22     ktm    79    1
# 6    ram   21     pkr    96    1
# 7   sita   19     jkp    91    0
# 8   nita   21     pkr    99    0

# %%
df['name']
# Out:
# 0      ram
# 1    shyam
# 2     sita
# 3     sita
# 4      ram
# 5      ram
# 6      ram
# 7     sita
# 8     nita
# Name: name, dtype: object

# %%
df[['name','age']]
# Out:
#     name  age
# 0    ram   22
# 1  shyam   21
# 2   sita   23
# 3   sita   19
# 4    ram   22
# 5    ram   22
# 6    ram   21
# 7   sita   19
# 8   nita   21

# %%
df['age'] > 20
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# Name: age, dtype: bool

# %%
df[df['age']>20]
# Out:
#     name  age address  mark  sex
# 0    ram   22     ktm    77    1
# 1  shyam   21     brt    81    1
# 2   sita   23     ktm    83    0
# 4    ram   22     ktm    77    1
# 5    ram   22     ktm    79    1
# 6    ram   21     pkr    96    1
# 8   nita   21     pkr    99    0

# %%
df['sex'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7     True
# 8    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#    name  age address  mark  sex
# 4   ram   22     ktm    77    1
# 7  sita   19     jkp    91    0

# %%
df[df['name'].duplicated()]
# Out:
#    name  age address  mark  sex
# 3  sita   19     jkp    91    0
# 4   ram   22     ktm    77    1
# 5   ram   22     ktm    79    1
# 6   ram   21     pkr    96    1
# 7  sita   19     jkp    91    0

# %%
df[df.duplicated(subset = 'name')]
# Out:
#    name  age address  mark  sex
# 3  sita   19     jkp    91    0
# 4   ram   22     ktm    77    1
# 5   ram   22     ktm    79    1
# 6   ram   21     pkr    96    1
# 7  sita   19     jkp    91    0

# %%
df
# Out:
#     name  age address  mark  sex
# 0    ram   22     ktm    77    1
# 1  shyam   21     brt    81    1
# 2   sita   23     ktm    83    0
# 3   sita   19     jkp    91    0
# 4    ram   22     ktm    77    1
# 5    ram   22     ktm    79    1
# 6    ram   21     pkr    96    1
# 7   sita   19     jkp    91    0
# 8   nita   21     pkr    99    0

# %%
df.drop(columns=['sex'])
# Out:
#     name  age address  mark
# 0    ram   22     ktm    77
# 1  shyam   21     brt    81
# 2   sita   23     ktm    83
# 3   sita   19     jkp    91
# 4    ram   22     ktm    77
# 5    ram   22     ktm    79
# 6    ram   21     pkr    96
# 7   sita   19     jkp    91
# 8   nita   21     pkr    99

# %%
df
# Out:
#     name  age address  mark  sex
# 0    ram   22     ktm    77    1
# 1  shyam   21     brt    81    1
# 2   sita   23     ktm    83    0
# 3   sita   19     jkp    91    0
# 4    ram   22     ktm    77    1
# 5    ram   22     ktm    79    1
# 6    ram   21     pkr    96    1
# 7   sita   19     jkp    91    0
# 8   nita   21     pkr    99    0

# %%
for item in df['sex']:
    print(item)
# Out:
# 1
# 1
# 0
# 0
# 1
# 1
# 1
# 0
# 0

# %%
new_data = []

for item in df['sex']:
    if item == 1:
        new_data.append("M")
    else:
        new_data.append("F")

df['sex_new'] = new_data

# %%
df
# Out:
#     name  age address  mark  sex sex_new
# 0    ram   22     ktm    77    1       M
# 1  shyam   21     brt    81    1       M
# 2   sita   23     ktm    83    0       F
# 3   sita   19     jkp    91    0       F
# 4    ram   22     ktm    77    1       M
# 5    ram   22     ktm    79    1       M
# 6    ram   21     pkr    96    1       M
# 7   sita   19     jkp    91    0       F
# 8   nita   21     pkr    99    0       F

# %%
df['sex_newer'] = ['M' if m ==1 else 'F' for m in df['sex']]

# %%
df
# Out:
#     name  age address  mark  sex sex_new sex_newer
# 0    ram   22     ktm    77    1       M         M
# 1  shyam   21     brt    81    1       M         M
# 2   sita   23     ktm    83    0       F         F
# 3   sita   19     jkp    91    0       F         F
# 4    ram   22     ktm    77    1       M         M
# 5    ram   22     ktm    79    1       M         M
# 6    ram   21     pkr    96    1       M         M
# 7   sita   19     jkp    91    0       F         F
# 8   nita   21     pkr    99    0       F         F

# %%
df = pd.read_csv('data_detail.csv')
df
# Out:
#    name  age address  mark  sex
# 0   ram   22     ktm  77.0    1
# 1   NaN   21     brt  81.0    1
# 2  sita   23     ktm  83.0    0
# 3  sita   19     jkp  91.0    0
# 4   ram   22     ktm  77.0    1
# 5   ram   22     ktm  79.0    1
# 6   ram   21     pkr   NaN    1
# 7  sita   19     jkp  91.0    0
# 8  nita   21     pkr  99.0    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     8 non-null      object
#  1   age      9 non-null      int64
#  2   address  9 non-null      object
#  3   mark     8 non-null      float64
#  4   sex      9 non-null      int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 492.0+ bytes

# %%
df.isna()
# Out:
#     name    age  address   mark    sex
# 0   True  False    False  False  False
# 1  False  False    False  False  False
# 2  False  False    False  False  False
# 3  False  False    False  False  False
# 4  False  False    False  False  False
# 5  False  False    False  False  False
# 6  False  False    False   True  False
# 7  False  False    False  False  False
# 8  False  False    False  False  False

# %%
df.ffill()
# Out:
#    name  age address  mark  sex
# 0   ram   22     ktm  77.0    1
# 1   ram   21     brt  81.0    1
# 2  sita   23     ktm  83.0    0
# 3  sita   19     jkp  91.0    0
# 4   ram   22     ktm  77.0    1
# 5   ram   22     ktm  79.0    1
# 6   ram   21     pkr  79.0    1
# 7  sita   19     jkp  91.0    0
# 8  nita   21     pkr  99.0    0

# %%
df
# Out:
#    name  age address  mark  sex
# 0   ram   22     ktm  77.0    1
# 1   NaN   21     brt  81.0    1
# 2  sita   23     ktm  83.0    0
# 3  sita   19     jkp  91.0    0
# 4   ram   22     ktm  77.0    1
# 5   ram   22     ktm  79.0    1
# 6   ram   21     pkr   NaN    1
# 7  sita   19     jkp  91.0    0
# 8  nita   21     pkr  99.0    0

# %%
df.dropna()
# Out:
#    name  age address  mark  sex
# 0   ram   22     ktm  77.0    1
# 2  sita   23     ktm  83.0    0
# 3  sita   19     jkp  91.0    0
# 4   ram   22     ktm  77.0    1
# 5   ram   22     ktm  79.0    1
# 7  sita   19     jkp  91.0    0
# 8  nita   21     pkr  99.0    0

# %%
df = pd.read_csv("student.csv")
df
# Out:
#     school sex  age address famsize Pstatus                           Medu  \
# 0       GP   F   18       U     GT3       A               higher education
# 1       GP   F   17       U     GT3       T  primary education (4th grade)
# 2       GP   F   15       U     LE3       T  primary education (4th grade)
# 3       GP   F   15       U     GT3       T               higher education
# 4       GP   F   16       U     GT3       T            secondary education
# ..     ...  ..  ...     ...     ...     ...                            ...
# 390     MS   M   20       U     LE3       A               5th to 9th grade
# 391     MS   M   17       U     LE3       T            secondary education
# 392     MS   M   21       R     GT3       T  primary education (4th grade)
# 393     MS   M   18       R     LE3       T            secondary education
# 394     MS   M   19       U     LE3       T  primary education (4th grade)
#
# ...

# %%
pd.crosstab(df['school'],df['age'])
# Out:
# age     15   16  17  18  19  20  21  22
# school
# GP      82  104  86  57  18   1   0   1
# MS       0    0  12  25   6   2   1   0

# %%
df['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
df.groupby(['school','age']).size()
# Out:
# school  age
# GP      15      82
#         16     104
#         17      86
#         18      57
#         19      18
#         20       1
#         22       1
# MS      17      12
#         18      25
#         19       6
#         20       2
#         21       1
# dtype: int64

# %%
df.groupby(['school','age','Medu']).size()
# Out:
# school  age  Medu
# GP      15   5th to 9th grade                 17
#              higher education                 38
#              primary education (4th grade)     9
#              secondary education              18
#         16   5th to 9th grade                 30
#              higher education                 35
#              none                              1
#              primary education (4th grade)    10
#              secondary education              28
#         17   5th to 9th grade                 26
#              higher education                 24
#              none                              1
#              primary education (4th grade)    14
#              secondary education              21
#         18   5th to 9th grade                 20
#              higher education                 20
#              primary education (4th grade)     5
#              secondary education              12
#         19   5th to 9th grade                  3
# ...
